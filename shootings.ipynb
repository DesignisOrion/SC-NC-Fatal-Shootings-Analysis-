# %% [markdown]
# # Fatal Shootings within the Carolinas
#
# After the verdict of Breonna Taylor many addressed their concerns via the media. It made me want to take a more in depth look of the fatal shootings within the states of North and South Carolina.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Overview of fatal shootings within the United States
#
# Here is all the data of the fatal shootings within United States. 2015 - 2020.

# %%
shootings = pd.read_csv('fatal-police-shootings-data.csv')
shootings
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5333  5815               TK TK  2020-05-20              shot           gun
# 5334  5836      Michael Snyder  2020-05-24              shot           gun
# 5335  5837      Gary P. Dorton  2020-05-25              shot         knife
# 5336  5839               TK TK  2020-05-25              shot           gun
# 5337  5838  John Allen Dunaway  2020-05-26  shot and Tasered  undetermined
#
# ...

# %% [markdown]
# # South Carolina
# Here is the insight to fatal deaths within South Carolina.

# %%
stateSC = shootings.loc[shootings['state']=='SC']
stateSC.to_csv('stateSC.csv')
stateSC
# Out:
#         id                     name        date   manner_of_death    armed  \
# 146    186         Chazsten Freeman  2015-02-28              shot      gun
# 226    240     Jeremy Lorenza Kelly  2015-03-25              shot      gun
# 255    297             Walter Scott  2015-04-04  shot and Tasered  unarmed
# 269    343          Phillip Burgess  2015-04-09              shot      gun
# 281    366              Dante Noble  2015-04-15              shot    knife
# ...    ...                      ...         ...               ...      ...
# 5222  5733  Joshua Dariandre Ruffin  2020-04-08              shot      gun
# 5247  5750       Marcus Eugene Epps  2020-04-17              shot    knife
# 5255  5759            Elmer L. Mack  2020-04-22              shot      gun
# 5310  5799    Ward Benjamin McClain  2020-05-09              shot      gun
# 5318  5829                Roy Ogden  2020-05-15              shot      gun
#
# ...

# %% [markdown]
# # Males in South Carolina
# Insight of males within South Carolina involved in fatal shootings

# %%
malesSC= shootings.loc[(shootings['state'] == 'SC') & (shootings['gender'] == 'M')]
malesSC.to_csv('malesSC.csv')
malesSC
# Out:
#         id                     name        date   manner_of_death    armed  \
# 146    186         Chazsten Freeman  2015-02-28              shot      gun
# 226    240     Jeremy Lorenza Kelly  2015-03-25              shot      gun
# 255    297             Walter Scott  2015-04-04  shot and Tasered  unarmed
# 269    343          Phillip Burgess  2015-04-09              shot      gun
# 281    366              Dante Noble  2015-04-15              shot    knife
# ...    ...                      ...         ...               ...      ...
# 5222  5733  Joshua Dariandre Ruffin  2020-04-08              shot      gun
# 5247  5750       Marcus Eugene Epps  2020-04-17              shot    knife
# 5255  5759            Elmer L. Mack  2020-04-22              shot      gun
# 5310  5799    Ward Benjamin McClain  2020-05-09              shot      gun
# 5318  5829                Roy Ogden  2020-05-15              shot      gun
#
# ...

# %% [markdown]
# # Females in South Carolina
# Insight of females within South Carolina involved in fatal shootings

# %%
femaleSC = shootings.loc[(shootings['state'] == 'SC') & (shootings['gender'] == 'F')]
femaleSC.to_csv('femaleSC.csv')
femaleSC
# Out:
#         id                name        date manner_of_death  armed   age  \
# 841    987       Laura Lemieux  2015-11-05            shot    gun  36.0
# 3643  3996  Stephanie B. Owens  2018-08-26            shot    gun  41.0
# 3763  4132     Kimberly Norris  2018-10-20            shot    gun  34.0
# 3901  4321       April Webster  2018-12-16            shot  knife  47.0
#
#      gender race               city state  signs_of_mental_illness  \
# 841       F    W        Goose Creek    SC                     True
# 3643      F    W         Blacksburg    SC                     True
# 3763      F    W  Darlington County    SC                    False
# 3901      F    B  Darlington County    SC                     True
#
#      threat_level         flee  body_camera
# 841        attack  Not fleeing        False
# 3643       attack  Not fleeing        False
# 3763       attack  Not fleeing         True
# 3901        other  Not fleeing        False

# %% [markdown]
# # North Carolina
# Here is the insight to fatal deaths within North Carolina.

# %%
stateNC = shootings.loc[shootings['state']=='NC']
stateNC.to_csv('stateNC.csv')
stateNC
# Out:
#         id                   name        date manner_of_death         armed  \
# 92     554            James Allen  2015-02-07            shot           gun
# 118    130           Betty Sexton  2015-02-17            shot           gun
# 123    163       Janisha Fonville  2015-02-18            shot  undetermined
# 150    191            Ian Sherrod  2015-02-28            shot           gun
# 172    274           Lester Brown  2015-03-09            shot           gun
# ...    ...                    ...         ...             ...           ...
# 5260  5752  Timothy Darryl Slides  2020-04-24            shot           gun
# 5283  5770    Kortney Shawn Price  2020-05-03            shot           gun
# 5298  5804     James Joseph James  2020-05-06            shot         knife
# 5308  5797        Jonathan Carter  2020-05-09            shot  undetermined
# 5314  5835   David Tylek Atkinson  2020-05-13            shot           gun
#
# ...

# %% [markdown]
# # Males in North Carolina
# Insight of males within North Carolina involved in fatal shootings

# %%
malesNC = shootings.loc[(shootings['state'] == 'NC') & (shootings['gender'] == 'M')]
malesNC.to_csv('malesNC.csv')
malesNC
# Out:
#         id                   name        date manner_of_death         armed  \
# 92     554            James Allen  2015-02-07            shot           gun
# 150    191            Ian Sherrod  2015-02-28            shot           gun
# 172    274           Lester Brown  2015-03-09            shot           gun
# 196    213     William Dean Poole  2015-03-16            shot           gun
# 198    217            Declan Owen  2015-03-17            shot           gun
# ...    ...                    ...         ...             ...           ...
# 5260  5752  Timothy Darryl Slides  2020-04-24            shot           gun
# 5283  5770    Kortney Shawn Price  2020-05-03            shot           gun
# 5298  5804     James Joseph James  2020-05-06            shot         knife
# 5308  5797        Jonathan Carter  2020-05-09            shot  undetermined
# 5314  5835   David Tylek Atkinson  2020-05-13            shot           gun
#
# ...

# %% [markdown]
# # Females in North Carolina
# Insight of females within North Carolina involved in fatal shootings.

# %%
femaleNC = shootings.loc[(shootings['state'] == 'NC') & (shootings['gender'] == 'F')]
femaleNC.to_csv('femaleNC.csv')
femaleNC
# Out:
#         id                  name        date manner_of_death         armed  \
# 118    130          Betty Sexton  2015-02-17            shot           gun
# 123    163      Janisha Fonville  2015-02-18            shot  undetermined
# 1309  1489  Kay Frances Campbell  2016-04-25            shot           gun
# 2478  2760           Tina Medlin  2017-07-08            shot           gun
# 4257  4690       April Robertson  2019-04-30            shot         knife
#
#        age gender race            city state  signs_of_mental_illness  \
# 118   43.0      F    W   Gaston County    NC                    False
# 123   20.0      F    B       Charlotte    NC                     True
# 1309  60.0      F    W  East Flat Rock    NC                     True
# 2478  50.0      F    W    Newton Grove    NC                    False
# 4257  45.0      F    W         Welcome    NC                    False
#
#      threat_level         flee  body_camera
# 118        attack  Not fleeing        False
# ...

# %% [markdown]
# # Author: Orion F.
